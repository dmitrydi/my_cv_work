# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = '0'
annotations_dir = '../data/cam_1_xml_hand'
images_dir = '../data/cam_1_imgs'

# %%
from darkflow.net.build import TFNet

# %%
build_path = 'test_build'

# %%
weights = os.path.join(build_path, 'bin', 'yolo.weights')
model = os.path.join(build_path, 'cfg', 'yolo.cfg')
cfg = os.path.join(build_path, 'cfg')
labels = os.path.join(build_path, 'labels.txt')

# %%
options=dict()
#options['gpu'] = 0.5
options['model'] = model
options['load'] = weights
options['config'] = cfg
options['labels'] = labels
options['train'] = True
options['dataset'] = images_dir
options['annotation'] = annotations_dir
options['epoch'] = 1
options['gpu'] = 1
options["batch"] = 1
options["subdivisions"] = 1

# %%
tfnet = TFNet(options)
# Out:
# Parsing test_build/cfg/yolo.cfg
# Loading test_build/bin/yolo.weights ...
# Successfully identified 203934260 bytes
# Finished in 0.07880306243896484s
# Model has a coco model name, loading coco labels.
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 608, 608, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 608, 608, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 304, 304, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 304, 304, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 152, 152, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 152, 152, 128)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 152, 152, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 152, 152, 128)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 76, 76, 128)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 76, 76, 256)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 76, 76, 128)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 76, 76, 256)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 38, 38, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 38, 38, 512)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 38, 38, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 38, 38, 512)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 38, 38, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 38, 38, 512)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 19, 19, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 19, 19, 1024)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 19, 19, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 19, 19, 1024)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 19, 19, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 19, 19, 1024)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 19, 19, 1024)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 19, 19, 1024)
#  Load  |  Yep!  | concat [16]                      | (?, 38, 38, 512)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 38, 38, 64)
#  Load  |  Yep!  | local flatten 2x2                | (?, 19, 19, 256)
#  Load  |  Yep!  | concat [27, 24]                  | (?, 19, 19, 1280)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 19, 19, 1024)
#  Load  |  Yep!  | conv 1x1p0_1    linear           | (?, 19, 19, 425)
# -------+--------+----------------------------------+---------------
# GPU mode with 1 usage
# test_build/cfg/yolo.cfg loss hyper-parameters:
# 	H       = 19
# 	W       = 19
# 	box     = 5
# 	classes = 80
# 	scales  = [1.0, 5.0, 1.0, 1.0]
# Building test_build/cfg/yolo.cfg loss
# INFO:tensorflow:Summary name test_build/cfg/yolo.cfg loss is illegal; using test_build/cfg/yolo.cfg_loss instead.
# Building test_build/cfg/yolo.cfg train op
# Finished in 8.846013307571411s

# %%
tfnet.train()
# Out:
# test_build/cfg/yolo.cfg parsing ../data/cam_1_xml_hand
# Parsing for ['person', 'bicycle', 'car', 'motorbike', 'aeroplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'sofa', 'pottedplant', 'bed', 'diningtable', 'toilet', 'tvmonitor', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']
# [====================>]100%  cframe_1264.xml
# Statistics:
# person: 4036
# Dataset size: 1425
# Dataset of 1425 instance(s)
# batch for step 0
# image name: cframe_1198.jpg
# Training statistics:
# 	Learning rate : 1e-05
# 	Batch size    : 1
# 	Epoch number  : 1
# 	Backup every  : 2000
# step 1 - loss 2.4967236518859863 - moving ave loss 2.4967236518859868
# batch for step 1
# image name: cframe_2016.jpg
# step 2 - loss 1.5075305700302124 - moving ave loss 2.3978043437004093
# batch for step 2
# image name: cframe_2359.jpg
# step 3 - loss 2.364455223083496 - moving ave loss 2.394469431638718
# batch for step 3
# image name: cframe_2046.jpg
# step 4 - loss 1.9767452478408813 - moving ave loss 2.3526970132589344
# batch for step 4
# image name: cframe_1938.jpg
# step 5 - loss 2.5291309356689453 - moving ave loss 2.3703404054999355
# batch for step 5
# image name: cframe_1280.jpg
# step 6 - loss 3.477896213531494 - moving ave loss 2.4810959863030915
# batch for step 6
# image name: cframe_1543.jpg
# step 7 - loss 4.047886371612549 - moving ave loss 2.637775024834037
# batch for step 7
# image name: cframe_1997.jpg
# step 8 - loss 2.3092041015625 - moving ave loss 2.6049179325068836
# batch for step 8
# image name: cframe_2103.jpg
# step 9 - loss 4.289827346801758 - moving ave loss 2.773408873936371
# batch for step 9
# image name: cframe_1771.jpg
# step 10 - loss 3.7039616107940674 - moving ave loss 2.866464147622141
# batch for step 10
# image name: cframe_2063.jpg
# step 11 - loss 1.1717442274093628 - moving ave loss 2.696992155600863
# batch for step 11
# image name: cframe_1515.jpg
# step 12 - loss 1.1841541528701782 - moving ave loss 2.5457083553277946
# batch for step 12
# image name: cframe_1936.jpg
# step 13 - loss 2.8765876293182373 - moving ave loss 2.578796282726839
# batch for step 13
# image name: cframe_1579.jpg
# step 14 - loss 2.4231011867523193 - moving ave loss 2.5632267731293874
# batch for step 14
# image name: cframe_1999.jpg
# step 15 - loss 2.2733969688415527 - moving ave loss 2.5342437927006043
# batch for step 15
# image name: cframe_2314.jpg
# step 16 - loss 2.241908311843872 - moving ave loss 2.505010244614931
# batch for step 16
# image name: cframe_2245.jpg
# step 17 - loss 1.4348080158233643 - moving ave loss 2.397990021735774
# batch for step 17
# image name: cframe_1209.jpg
# step 18 - loss 3.26509165763855 - moving ave loss 2.4847001853260515
# batch for step 18
# image name: cframe_1696.jpg
# step 19 - loss 3.5920796394348145 - moving ave loss 2.595438130736928
# batch for step 19
# image name: cframe_1159.jpg
# step 20 - loss 1.0956193208694458 - moving ave loss 2.44545624975018
# batch for step 20
# image name: cframe_2120.jpg
# step 21 - loss 1.5194650888442993 - moving ave loss 2.352857133659592
# batch for step 21
# image name: cframe_1059.jpg
# step 22 - loss 1.2246534824371338 - moving ave loss 2.2400367685373466
# batch for step 22
# image name: cframe_2114.jpg
# step 23 - loss 3.634944200515747 - moving ave loss 2.3795275117351866
# batch for step 23
# image name: cframe_1412.jpg
# step 24 - loss 1.4605317115783691 - moving ave loss 2.287627931719505
# batch for step 24
# image name: cframe_1371.jpg
# step 25 - loss 2.44521164894104 - moving ave loss 2.3033863034416586
# batch for step 25
# image name: cframe_2285.jpg
# step 26 - loss 1.5064703226089478 - moving ave loss 2.2236947053583873
# batch for step 26
# image name: cframe_164.jpg
# step 27 - loss 2.4793949127197266 - moving ave loss 2.249264726094521
# batch for step 27
# image name: cframe_1536.jpg
# step 28 - loss 3.6953036785125732 - moving ave loss 2.3938686213363267
# batch for step 28
# image name: cframe_1213.jpg
# step 29 - loss 2.4711451530456543 - moving ave loss 2.4015962745072597
# batch for step 29
# image name: cframe_2299.jpg
# step 30 - loss 1.8691763877868652 - moving ave loss 2.3483542858352204
# batch for step 30
# image name: cframe_2204.jpg
# step 31 - loss 2.461545705795288 - moving ave loss 2.3596734278312272
# batch for step 31
# image name: cframe_1268.jpg
# step 32 - loss 2.529630422592163 - moving ave loss 2.376669127307321
# batch for step 32
# image name: cframe_1338.jpg
# step 33 - loss 2.117532253265381 - moving ave loss 2.350755439903127
# batch for step 33
# image name: cframe_1547.jpg
# step 34 - loss 0.4699084758758545 - moving ave loss 2.1626707435004002
# batch for step 34
# image name: cframe_2190.jpg
# step 35 - loss 2.155277967453003 - moving ave loss 2.1619314658956608
# batch for step 35
# image name: cframe_2013.jpg
# step 36 - loss 3.4025840759277344 - moving ave loss 2.285996726898868
# batch for step 36
# image name: cframe_1072.jpg
# step 37 - loss 3.075948476791382 - moving ave loss 2.3649919018881196
# batch for step 37
# image name: cframe_2194.jpg
# step 38 - loss 3.8290252685546875 - moving ave loss 2.511395238554776
# batch for step 38
# image name: cframe_1869.jpg
# step 39 - loss 1.3759452104568481 - moving ave loss 2.3978502357449836
# batch for step 39
# image name: cframe_1465.jpg
# step 40 - loss 2.669830799102783 - moving ave loss 2.4250482920807634
# batch for step 40
# image name: cframe_1406.jpg
# step 41 - loss 1.9678349494934082 - moving ave loss 2.379326957822028
# batch for step 41
# image name: cframe_1379.jpg
# step 42 - loss 1.5287336111068726 - moving ave loss 2.2942676231505126
# batch for step 42
# image name: cframe_1809.jpg
# step 43 - loss 0.7790071964263916 - moving ave loss 2.1427415804781007
# batch for step 43
# image name: cframe_1689.jpg
# step 44 - loss 1.6936753988265991 - moving ave loss 2.0978349623129504
# batch for step 44
# image name: cframe_1702.jpg
# step 45 - loss 1.1717411279678345 - moving ave loss 2.0052255788784388
# batch for step 45
# image name: cframe_1277.jpg
# step 46 - loss 1.7003990411758423 - moving ave loss 1.9747429251081792
# batch for step 46
# image name: cframe_1755.jpg
# step 47 - loss 1.4597749710083008 - moving ave loss 1.9232461296981913
# batch for step 47
# image name: cframe_1679.jpg
# step 48 - loss 0.8197113871574402 - moving ave loss 1.8128926554441163
# batch for step 48
# image name: cframe_1229.jpg
# step 49 - loss 3.215986728668213 - moving ave loss 1.9532020627665259
# batch for step 49
# image name: cframe_1396.jpg
# step 50 - loss 0.7009089589118958 - moving ave loss 1.827972752381063
# batch for step 50
# image name: cframe_1729.jpg
# step 51 - loss 0.8663787245750427 - moving ave loss 1.731813349600461
# batch for step 51
# image name: cframe_1703.jpg
# step 52 - loss 1.6683292388916016 - moving ave loss 1.725464938529575
# batch for step 52
# image name: cframe_2066.jpg
# step 53 - loss 1.8960741758346558 - moving ave loss 1.7425258622600832
# batch for step 53
# image name: cframe_2310.jpg
# step 54 - loss 1.5612555742263794 - moving ave loss 1.7243988334567129
# batch for step 54
# image name: cframe_2287.jpg
# step 55 - loss 3.0986268520355225 - moving ave loss 1.8618216353145938
# batch for step 55
# image name: cframe_1711.jpg
# step 56 - loss 3.1625256538391113 - moving ave loss 1.9918920371670457
# batch for step 56
# image name: cframe_1384.jpg
# step 57 - loss 3.260270595550537 - moving ave loss 2.118729893005395
# batch for step 57
# image name: cframe_1687.jpg
# step 58 - loss 3.7294294834136963 - moving ave loss 2.2797998520462253
# batch for step 58
# image name: cframe_192.jpg
# step 59 - loss 0.8511325716972351 - moving ave loss 2.1369331240113265
# batch for step 59
# image name: cframe_1133.jpg
# step 60 - loss 2.623100996017456 - moving ave loss 2.1855499112119396
# batch for step 60
# image name: cframe_1212.jpg
# step 61 - loss 2.8311607837677 - moving ave loss 2.2501109984675156
# batch for step 61
# image name: cframe_1890.jpg
# step 62 - loss 2.429880380630493 - moving ave loss 2.268087936683813
# batch for step 62
# image name: cframe_1667.jpg
# step 63 - loss 1.7872483730316162 - moving ave loss 2.2200039803185936
# batch for step 63
# image name: cframe_1776.jpg
# step 64 - loss 2.582085609436035 - moving ave loss 2.256212143230338
# batch for step 64
# image name: cframe_16.jpg
# step 65 - loss 2.891920566558838 - moving ave loss 2.319782985563188
# batch for step 65
# image name: cframe_10.jpg
# step 66 - loss 0.9750221967697144 - moving ave loss 2.1853069066838406
# batch for step 66
# image name: cframe_1075.jpg
# step 67 - loss 1.505906581878662 - moving ave loss 2.1173668742033227
# batch for step 67
# image name: cframe_2153.jpg
# step 68 - loss 0.6164659857749939 - moving ave loss 1.96727678536049
# batch for step 68
# image name: cframe_1654.jpg
# step 69 - loss 1.3013391494750977 - moving ave loss 1.9006830217719508
# batch for step 69
# image name: cframe_2334.jpg
# step 70 - loss 1.3922014236450195 - moving ave loss 1.8498348619592577
# batch for step 70
# image name: cframe_1065.jpg
# step 71 - loss 3.7476775646209717 - moving ave loss 2.0396191322254293
# batch for step 71
# image name: cframe_1449.jpg
# step 72 - loss 1.3519219160079956 - moving ave loss 1.970849410603686
# batch for step 72
# image name: cframe_1355.jpg
# step 73 - loss 0.7344554662704468 - moving ave loss 1.8472100161703622
# batch for step 73
# image name: cframe_1522.jpg
# step 74 - loss 0.6307975053787231 - moving ave loss 1.7255687650911984
# batch for step 74
# image name: cframe_1807.jpg
# step 75 - loss 0.7954973578453064 - moving ave loss 1.6325616243666092
# batch for step 75
# image name: cframe_2033.jpg
# step 76 - loss 1.9828516244888306 - moving ave loss 1.6675906243788314
# batch for step 76
# image name: cframe_1887.jpg
# step 77 - loss 4.43258810043335 - moving ave loss 1.9440903719842832
# batch for step 77
# image name: cframe_1214.jpg
# step 78 - loss 1.8168784379959106 - moving ave loss 1.9313691785854459
# batch for step 78
# image name: cframe_2320.jpg
# step 79 - loss 1.954350471496582 - moving ave loss 1.9336673078765596
# batch for step 79
# image name: cframe_169.jpg
# step 80 - loss 1.6047043800354004 - moving ave loss 1.9007710150924437
# batch for step 80
# image name: cframe_1534.jpg
# step 81 - loss 2.4992198944091797 - moving ave loss 1.9606159030241173
# batch for step 81
# image name: cframe_1273.jpg
# step 82 - loss 2.99556565284729 - moving ave loss 2.0641108780064346
# batch for step 82
# image name: cframe_2137.jpg
# step 83 - loss 2.3528811931610107 - moving ave loss 2.0929879095218924
# batch for step 83
# image name: cframe_180.jpg
# step 84 - loss 0.6646687984466553 - moving ave loss 1.9501559984143686
# batch for step 84
# image name: cframe_2315.jpg
# step 85 - loss 2.2109932899475098 - moving ave loss 1.9762397275676826
# batch for step 85
# image name: cframe_2290.jpg
# step 86 - loss 0.6901310086250305 - moving ave loss 1.8476288556734175
# batch for step 86
# image name: cframe_116.jpg
# step 87 - loss 1.061591386795044 - moving ave loss 1.7690251087855802
# batch for step 87
# image name: cframe_1323.jpg
# step 88 - loss 0.6404344439506531 - moving ave loss 1.6561660423020874
# batch for step 88
# image name: cframe_1675.jpg
# step 89 - loss 1.9577547311782837 - moving ave loss 1.6863249111897072
# batch for step 89
# image name: cframe_1304.jpg
# step 90 - loss 2.4259896278381348 - moving ave loss 1.76029138285455
# batch for step 90
# image name: cframe_2003.jpg
# step 91 - loss 1.520782709121704 - moving ave loss 1.7363405154812654
# batch for step 91
# image name: cframe_1744.jpg
# step 92 - loss 1.4670902490615845 - moving ave loss 1.7094154888392974
# batch for step 92
# image name: cframe_2207.jpg
# step 93 - loss 2.321129560470581 - moving ave loss 1.7705868960024258
# batch for step 93
# image name: cframe_1318.jpg
# step 94 - loss 1.2398781776428223 - moving ave loss 1.7175160241664653
# batch for step 94
# image name: cframe_1366.jpg
# step 95 - loss 3.670644760131836 - moving ave loss 1.9128288977630024
# batch for step 95
# image name: cframe_2221.jpg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-32415d061bd8> in <module>()
# ----> 1 tfnet.train()
#
# ~/.local/lib/python3.5/site-packages/darkflow/net/flow.py in train(self)
#      37     loss_op = self.framework.loss
#      38
# ---> 39     for i, (x_batch, datum) in enumerate(batches):
#      40         if not i: self.say(train_stats.format(
#      41             self.FLAGS.lr, self.FLAGS.batch,
#
# ~/.local/lib/python3.5/site-packages/darkflow/net/yolo/data.py in shuffle(self)
#     127                     ])
#     128
# --> 129             x_batch = np.concatenate(x_batch, 0)
#     130             yield x_batch, feed_batch
#     131
#
# ValueError: need at least one array to concatenate
