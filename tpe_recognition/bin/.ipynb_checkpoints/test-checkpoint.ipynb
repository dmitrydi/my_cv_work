# %%
import face_detector
# Out:
# Using TensorFlow backend.

# %%
video_file = 'C:/my_cv_work/data/long/long_video.avi'
saving_dir = 'C:/my_cv_work/data/pics/test_facenet'
face_detector.get_people_from_video(video_file, saving_dir)
# Out:
# trying to rescue tracker for p_id 2
# failed
# trying to rescue tracker for p_id 1
# failed
# 1161

# %%
from cnn_model_builder import *

# %%
model = build_cnn(120,60,30)

# %%
n_samples_train = 3000
n_samples_test = 600
nepoch = 50
batch_size = 100
img_height = 120
img_width = 60

train_path = 'C:\\my_cv_work\\data\\pics\\people_for_model\\train'
test_path = 'C:\\my_cv_work\\data\\pics\\people_for_model\\test'

# %%
train_save_cnn(model,train_path=train_path,test_path=test_path,rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)

# %%
from tpe_train import train_tpe_from_dirs
model_name = 'tpe_model_test.h5'
from keras.models import load_model
model = load_model('../models/people_model_2.h5')
# Out:
# Using TensorFlow backend.

# %%
train_tpe_from_dirs(model,model_saving_name=model_name,nepoch=100)
# Out:
# Found 3000 images belonging to 30 classes.
# C:\ProgramData\Anaconda3\lib\site-packages\keras\preprocessing\image.py:506: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn'tbeen fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Found 600 images belonging to 30 classes.
# c:\my_cv_work\tpe_recognition\bin\tpe_model_builder.py:43: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(64, input_dim=64, weights=[array([[ ..., activation="linear", use_bias=False)`
#   base_model.add(Dense(n_out, input_dim=n_in, bias=False, weights=[W_pca], activation='linear'))
# c:\my_cv_work\tpe_recognition\bin\tpe_model_builder.py:49: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   e = merge([a_emb, p_emb, n_emb], mode=triplet_merge, output_shape=triplet_merge_shape)
# ...
